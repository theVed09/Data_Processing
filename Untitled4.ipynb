# %% [markdown]
# <a href="https://colab.research.google.com/github/theVed09/Data_Processing/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Nagpur.csv")
df.dropna(subset=['Latitude'], inplace=True)
# Out:
# 0

# %%
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt

coords = df[['Longitude','Latitude']]

distortions = []
K = range(1,25)
for k in K:
    kmeansModel = KMeans(n_clusters=k)
    kmeansModel = kmeansModel.fit(coords)
    distortions.append(kmeansModel.inertia_)

# Calculate the derivative of distortions
d_distortions = np.diff(distortions)

# Find the elbow point where the rate of change starts to slow
elbow_point = np.where(d_distortions == d_distortions.min())[0][0] + 1

print(f'The optimal number of clusters is {elbow_point}')

fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(K, distortions, marker='o')
plt.xlabel('k')
plt.ylabel('Distortions')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.metrics import silhouette_score

sil = []
kmax = 50

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
  kmeans = KMeans(n_clusters = k).fit(coords)
  labels = kmeans.labels_
  sil.append(silhouette_score(coords, labels, metric = 'euclidean'))
sil

# %%
len(sil)
# Out:
# 49

# %%
kmeans = KMeans(n_clusters=len(sil), init='k-means++')
kmeans.fit(coords)
y = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df['cluster'] = kmeans.predict(df[['Longitude','Latitude']])
df.head()
# Out:
#    Unnamed: 0             Restaurant Name  \
# 0           0             Biryani By Kilo
# 1           1  Haldirams Sweets & Namkeen
# 4           4        Jay Ambika Bhojnalay
# 6           6                      Subway
# 9           9                 Babbu Hotel
#
#                                             Category  Rating  Cost for two  \
# 0  Biryani,Mughlai,Kebabs,Hyderabadi,North Indian...     4.1           600
# 1                            Sweets,Bakery,Beverages     4.6           300
# 4                                North Indian,Indian     4.0           300
# 6      Healthy Food,Salads,Snacks,Desserts,Beverages     4.1           350
# 9             Biryani,Mughlai,North Indian,Beverages     3.7           300
#
#                 Area    Locality  \
# 0         Khare Town  Dharampeth
# 1          Sitabuldi   SITABULDI
# 4  Ganeshpeth Colony  Gandhibagh
# 6         Khare Town  Dharampeth
# 9          Mominpura  Gandhibagh
#
#                                              Address    Veg   Latitude  \
# 0  Commercial First Floor, F1 & F2 INDU YASH II, ...  False  21.140968
# 1                   ABHYANKAR ROAD, SITABULDI,NAGPUR  False  21.141448
# 4    Shop no13 opp. Rahul hotel Ganeshpeth bus stand   True  21.154327
# 6  G2, Indu Yash Complex, Cement Road, Ramnagar, ...  False  21.140968
# 9  Near Bakra Mandi, Mominpura Chowk, Mominpura, ...  False  21.154327
#
#    Longitude  cluster
# 0  79.062434       10
# 1  79.082484       16
# 4  79.105853        9
# 6  79.062434       10
# 9  79.105853        9

# %%
df['Rating'].fillna(0, inplace=True)

# %%
from scipy.spatial import cKDTree

def find_same_cluster(df, Latitude, Longitude, count=20):
    # Convert input data to DataFrame with feature names
    input_data = pd.DataFrame([[Latitude, Longitude]], columns=['Latitude', 'Longitude'])

    # Create a cKDTree object for fast nearest neighbor search
    tree = cKDTree(df[['Latitude', 'Longitude']])

    # Find the nearest neighbor to the input location
    _, idx = tree.query(input_data, k=1)

    # Get the cluster of the nearest neighbor
    cluster = df.iloc[idx[0]]['cluster']

    # Filter the rows in the dataframe that belong to the same cluster
    same_cluster_data = df[df['cluster'] == cluster]

    # Sort the restaurants by rating
    top_restaurants = same_cluster_data.sort_values(by=['Rating'], ascending=False)

    # Get the top 'count' restaurants
    top_restaurants = top_restaurants.head(count)

    return top_restaurants

# %%
top_3_places_in_nagpur = [21.140968,79.062434]

result = find_same_cluster(df,top_3_places_in_nagpur[0],top_3_places_in_nagpur[1],count=10)
result
# Out:
#      Unnamed: 0                     Restaurant Name  \
# 248         248               Amazing Blazing Cakes
# 255         255  Reddy's Gokul Brindavan Restaurant
# 396         396               Biryani Bazar By Kilo
# 293         293  Reddy's Gokul Dairy And Agro Farms
# 366         366                   Collective Blends
# 421         421          Dahiya Momos (Bajaj Nagar)
# 619         619                        Khichdi king
# 483         483                        We Feed More
# 407         407                        Bombay Kulfi
# 555         555                  Pankaj Chat Center
#
#                                            Category  Rating  Cost for two  \
# 248                                Bakery,Beverages     4.6           300
# 255                          South Indian,Beverages     4.5           150
# 396              Biryani,North Indian,Kebabs,Indian     4.4           200
# 293                       Sweets,Beverages,Desserts     4.4           200
# 366  Continental,Beverages,American,Mexican,Italian     4.4           300
# 421                                    North Indian     4.4           200
# 619                             Indian,Healthy Food     4.4           200
# 483                                          Indian     4.3           200
# 407                    Ice Cream,Desserts,Beverages     4.3           150
# 555                        Street Food,Indian,Chaat     4.3           100
#
#             Area    Locality  \
# 248   Dharampeth  Dharampeth
# 255   Dharampeth  Dharampeth
# 396   Dharampeth  Dharampeth
# 293   Dharampeth  Dharampeth
# 366   Khare Town  Dharampeth
# 421  Bajaj Nagar  Dharampeth
# 619   Dharampeth  Dharampeth
# 483  LAXMI NAGAR  Dharampeth
# 407   Dharampeth  Dharampeth
# 555   Dharampeth  Dharampeth
#
#                                                Address    Veg   Latitude  \
# 248  4-1, Near Akankar Theatre, Pratibha Sankul  Ap...  False  21.140968
# 255           WHC Road, Laxminagar, Dharampeth, Nagpur   True  21.140968
# 396  Flat no 102, Satyam Apartment Canal road, Goku...  False  21.140968
# 293  PLOT NO 72, HOUSE NO451, AGRESEN MARGROAD, DHA...  False  21.140968
# 366  23B, near HDFC bank, Om Sai Nagar, Shivaji Nag...  False  21.140968
# 421                 PLOT NO 10, ABHYANKAR NAGAR NAGPUR  False  21.140968
# 619  553/E/3, Laxminagar, Nagpur, Maharashtra 44002...   True  21.140968
# 483  275 Anant Kamal Complex Laxmi Nagar Nagpur 440022  False  21.140968
# 407  285, Buty Plot, Hanuman Mandir Rd, Beside Goku...   True  21.140968
# 555  ABHYANKAR NAGAR ROAD ABHYANKAR NAGAR NAGPUR NA...   True  21.140968
#
#      Longitude  cluster
# 248  79.062434       10
# 255  79.062434       10
# 396  79.062434       10
# 293  79.062434       10
# 366  79.062434       10
# 421  79.062434       10
# 619  79.062434       10
# 483  79.062434       10
# 407  79.062434       10
# 555  79.062434       10
